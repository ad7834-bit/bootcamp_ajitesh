# %% [markdown]
# ### Load api_key from `.env/`

# %%
import os
from dotenv import load_dotenv
import requests

load_dotenv()

api_key = os.getenv("API_KEY")

# %% [markdown]
# ### API Pull

# %%
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY_ADJUSTED&symbol=IBM&apikey={api_key}'
r = requests.get(url)
data = r.json()

data['Monthly Adjusted Time Series']
# Out:
# {'2025-08-20': {'1. open': '251.4050',
#   '2. high': '255.0000',
#   '3. low': '233.3600',
#   '4. close': '242.5500',
#   '5. adjusted close': '242.5500',
#   '6. volume': '80443917',
#   '7. dividend amount': '1.6800'},
#  '2025-07-31': {'1. open': '294.5500',
#   '2. high': '295.6100',
#   '3. low': '252.2200',
#   '4. close': '253.1500',
#   '5. adjusted close': '251.4066',
#   '6. volume': '109055173',
#   '7. dividend amount': '0.0000'},
#  '2025-06-30': {'1. open': '257.8500',
#   '2. high': '296.1600',
#   '3. low': '257.2200',
#   '4. close': '294.7800',
#   '5. adjusted close': '292.7500',
#   '6. volume': '74395935',
#   '7. dividend amount': '0.0000'},
#  '2025-05-30': {'1. open': '241.4400',
#   '2. high': '269.2800',
#   '3. low': '237.9450',
#   '4. close': '259.0600',
#   '5. adjusted close': '257.2759',
#   '6. volume': '78164014',
#   '7. dividend amount': '1.6800'},
#  '2025-04-30': {'1. open': '248.0300',
#   '2. high': '252.7900',
#   '3. low': '214.5000',
#   '4. close': '241.8200',
#   '5. adjusted close': '238.5465',
#   '6. volume': '120775331',
#   '7. dividend amount': '0.0000'},
#  '2025-03-31': {'1. open': '254.7350',
#   '2. high': '266.4500',
#   '3. low': '237.2240',
#   '4. close': '248.6600',
#   '5. adjusted close': '245.2939',
#   '6. volume': '100813990',
#   '7. dividend amount': '0.0000'},
#  '2025-02-28': {'1. open': '252.4000',
#   '2. high': '265.7200',
#   '3. low': '246.5400',
#   '4. close': '252.4400',
#   '5. adjusted close': '249.0227',
#   '6. volume': '94123851',
#   '7. dividend amount': '1.6700'},
#  '2025-01-31': {'1. open': '221.8200',
#   '2. high': '261.8000',
#   '3. low': '214.6100',
#   '4. close': '255.7000',
#   '5. adjusted close': '250.5600',
#   '6. volume': '92424171',
#   '7. dividend amount': '0.0000'},
#  '2024-12-31': {'1. open': '227.5000',
#   '2. high': '239.3500',
#   '3. low': '217.6523',
#   '4. close': '219.8300',
#   '5. adjusted close': '215.4110',
#   '6. volume': '81535689',
#   '7. dividend amount': '0.0000'},
#  '2024-11-29': {'1. open': '207.7700',
#   '2. high': '230.3600',
#   '3. low': '204.0700',
#   '4. close': '227.4100',
#   '5. adjusted close': '222.8386',
#   '6. volume': '77280587',
#   '7. dividend amount': '1.6700'},
#  '2024-10-31': {'1. open': '220.6300',
#   '2. high': '237.3700',
#   '3. low': '203.5100',
#   '4. close': '206.7200',
#   '5. adjusted close': '200.9728',
#   '6. volume': '105624376',
#   '7. dividend amount': '0.0000'},
#  '2024-09-30': {'1. open': '201.9100',
#   '2. high': '224.1500',
#   '3. low': '199.3350',
#   '4. close': '221.0800',
#   '5. adjusted close': '214.9336',
#   '6. volume': '83415811',
#   '7. dividend amount': '0.0000'},
#  '2024-08-30': {'1. open': '192.8100',
#   '2. high': '202.1700',
#   '3. low': '181.8100',
#   '4. close': '202.1300',
#   '5. adjusted close': '196.5105',
#   '6. volume': '65453729',
#   '7. dividend amount': '1.6700'},
#  '2024-07-31': {'1. open': '173.4500',
#   '2. high': '196.2600',
#   '3. low': '173.3800',
#   '4. close': '192.1400',
#   '5. adjusted close': '185.1829',
#   '6. volume': '81258646',
#   '7. dividend amount': '0.0000'},
#  '2024-06-28': {'1. open': '166.5400',
#   '2. high': '178.4599',
#   '3. low': '163.5300',
#   '4. close': '172.9500',
#   '5. adjusted close': '166.6877',
#   '6. volume': '70706301',
#   '7. dividend amount': '0.0000'},
#  '2024-05-31': {'1. open': '165.6900',
#   '2. high': '175.4600',
#   '3. low': '162.6200',
#   '4. close': '166.8500',
#   '5. adjusted close': '160.8086',
#   '6. volume': '78620355',
#   '7. dividend amount': '1.6700'},
#  '2024-04-30': {'1. open': '190.0000',
#   '2. high': '193.2800',
#   '3. low': '165.2605',
#   '4. close': '166.2000',
#   '5. adjusted close': '158.5893',
#   '6. volume': '98297181',
#   '7. dividend amount': '0.0000'},
#  '2024-03-28': {'1. open': '185.4900',
#   '2. high': '199.1800',
#   '3. low': '185.1800',
#   '4. close': '190.9600',
#   '5. adjusted close': '182.2154',
#   '6. volume': '99921776',
#   '7. dividend amount': '0.0000'},
#  '2024-02-29': {'1. open': '183.6300',
#   '2. high': '188.9500',
#   '3. low': '178.7500',
#   '4. close': '185.0300',
#   '5. adjusted close': '176.5570',
#   '6. volume': '88679550',
#   '7. dividend amount': '1.6600'},
#  '2024-01-31': {'1. open': '162.8300',
#   '2. high': '196.9000',
#   '3. low': '157.8850',
#   '4. close': '183.6600',
#   '5. adjusted close': '173.6858',
#   '6. volume': '128121557',
#   '7. dividend amount': '0.0000'},
#  '2023-12-29': {'1. open': '158.4100',
#   '2. high': '166.3400',
#   '3. low': '158.0000',
#   '4. close': '163.5500',
#   '5. adjusted close': '154.6680',
#   '6. volume': '87358302',
#   '7. dividend amount': '0.0000'},
#  '2023-11-30': {'1. open': '145.0000',
#   '2. high': '158.6000',
#   '3. low': '144.4500',
#   '4. close': '158.5600',
#   '5. adjusted close': '149.9490',
#   '6. volume': '78460252',
#   '7. dividend amount': '1.6600'},
#  '2023-10-31': {'1. open': '140.0400',
#   '2. high': '144.7600',
#   '3. low': '135.8700',
#   '4. close': '144.6400',
#   '5. adjusted close': '135.2536',
#   '6. volume': '94386980',
#   '7. dividend amount': '0.0000'},
#  '2023-09-29': {'1. open': '147.2600',
#   '2. high': '151.9299',
#   '3. low': '139.6100',
#   '4. close': '140.3000',
#   '5. adjusted close': '131.1953',
#   '6. volume': '82806487',
#   '7. dividend amount': '0.0000'},
#  '2023-08-31': {'1. open': '144.2500',
#   '2. high': '147.7275',
#   '3. low': '139.7600',
#   '4. close': '146.8300',
#   '5. adjusted close': '137.3015',
#   '6. volume': '84274205',
#   '7. dividend amount': '1.6600'},
#  '2023-07-31': {'1. open': '133.4200',
#   '2. high': '144.6050',
#   '3. low': '131.5500',
#   '4. close': '144.1800',
#   '5. adjusted close': '133.2709',
#   '6. volume': '85778938',
#   '7. dividend amount': '0.0000'},
#  '2023-06-30': {'1. open': '128.4400',
#   '2. high': '139.4690',
#   '3. low': '127.7800',
#   '4. close': '133.8100',
#   '5. adjusted close': '123.6855',
#   '6. volume': '100722016',
#   '7. dividend amount': '0.0000'},
#  '2023-05-31': {'1. open': '126.3500',
#   '2. high': '130.0699',
#   '3. low': '120.5500',
#   '4. close': '128.5900',
#   '5. adjusted close': '118.8605',
#   '6. volume': '95710890',
#   '7. dividend amount': '1.6600'},
#  '2023-04-28': {'1. open': '130.9700',
#   '2. high': '132.6100',
#   '3. low': '124.5600',
#   '4. close': '126.4100',
#   '5. adjusted close': '115.2663',
#   '6. volume': '83664114',
#   '7. dividend amount': '0.0000'},
#  '2023-03-31': {'1. open': '128.9000',
#   '2. high': '131.4800',
#   '3. low': '121.7100',
#   '4. close': '131.0900',
#   '5. adjusted close': '119.5337',
#   '6. volume': '138093084',
#   '7. dividend amount': '0.0000'},
#  '2023-02-28': {'1. open': '134.4900',
#   '2. high': '137.3900',
#   '3. low': '128.8600',
#   '4. close': '129.3000',
#   '5. adjusted close': '117.9015',
#   '6. volume': '76080679',
#   '7. dividend amount': '1.6500'},
#  '2023-01-31': {'1. open': '141.1000',
#   '2. high': '147.1800',
#   '3. low': '132.9800',
#   '4. close': '134.7300',
#   '5. adjusted close': '121.3557',
#   '6. volume': '105576019',
#   '7. dividend amount': '0.0000'},
#  '2022-12-30': {'1. open': '149.9800',
#   '2. high': '153.2100',
#   '3. low': '137.1950',
#   '4. close': '140.8900',
#   '5. adjusted close': '126.9042',
#   '6. volume': '86426226',
#   '7. dividend amount': '0.0000'},
#  '2022-11-30': {'1. open': '138.2500',
#   '2. high': '150.4600',
#   '3. low': '133.9700',
#   '4. close': '148.9000',
#   '5. adjusted close': '134.1191',
#   '6. volume': '93620235',
#   '7. dividend amount': '1.6500'},
#  '2022-10-31': {'1. open': '120.1600',
#   '2. high': '138.8615',
#   '3. low': '115.5450',
#   '4. close': '138.2900',
#   '5. adjusted close': '123.0841',
#   '6. volume': '113480787',
#   '7. dividend amount': '0.0000'},
#  '2022-09-30': {'1. open': '128.4000',
#   '2. high': '130.9900',
#   '3. low': '118.6100',
#   '4. close': '118.8100',
#   '5. adjusted close': '105.7461',
#   '6. volume': '87256958',
#   '7. dividend amount': '0.0000'},
#  '2022-08-31': {'1. open': '130.7500',
#   '2. high': '139.3400',
#   '3. low': '128.4000',
#   '4. close': '128.4500',
#   '5. adjusted close': '114.3261',
#   '6. volume': '77392342',
#   '7. dividend amount': '1.6500'},
#  '2022-07-29': {'1. open': '141.0000',
#   '2. high': '141.8700',
#   '3. low': '125.1300',
#   '4. close': '130.7900',
#   '5. adjusted close': '114.9439',
#   '6. volume': '129801061',
#   '7. dividend amount': '0.0000'},
#  '2022-06-30': {'1. open': '139.6700',
#   '2. high': '144.7300',
#   '3. low': '132.8500',
#   '4. close': '141.1900',
#   '5. adjusted close': '124.0839',
#   '6. volume': '105815743',
#   '7. dividend amount': '0.0000'},
#  '2022-05-31': {'1. open': '133.0000',
#   '2. high': '139.8300',
#   '3. low': '125.8000',
#   '4. close': '138.8400',
#   '5. adjusted close': '122.0186',
#   '6. volume': '113207659',
#   '7. dividend amount': '1.6500'},
#  '2022-04-29': {'1. open': '129.6600',
#   '2. high': '141.8800',
#   '3. low': '124.9100',
#   '4. close': '132.2100',
#   '5. adjusted close': '114.7832',
#   '6. volume': '107525264',
#   '7. dividend amount': '0.0000'},
#  '2022-03-31': {'1. open': '122.6700',
#   '2. high': '133.0800',
#   '3. low': '120.7000',
#   '4. close': '130.0200',
#   '5. adjusted close': '112.8818',
#   '6. volume': '96447210',
#   '7. dividend amount': '0.0000'},
#  '2022-02-28': {'1. open': '133.7600',
#   '2. high': '138.8200',
#   '3. low': '118.8100',
#   '4. close': '122.5100',
#   '5. adjusted close': '106.3617',
#   '6. volume': '98492968',
#   '7. dividend amount': '1.6400'},
#  '2022-01-31': {'1. open': '134.0700',
#   '2. high': '142.2000',
#   '3. low': '124.1930',
#   '4. close': '133.5700',
#   '5. adjusted close': '114.5568',
#   '6. volume': '147238382',
#   '7. dividend amount': '0.0000'},
#  '2021-12-31': {'1. open': '118.2500',
#   '2. high': '134.9900',
#   '3. low': '116.5600',
#   '4. close': '133.6600',
#   '5. adjusted close': '114.6340',
#   '6. volume': '113930079',
#   '7. dividend amount': '0.0000'},
#  '2021-11-30': {'1. open': '125.0500',
#   '2. high': '127.2900',
#   '3. low': '114.5600',
#   '4. close': '117.1000',
#   '5. adjusted close': '100.4313',
#   '6. volume': '119252012',
#   '7. dividend amount': '1.6400'},
#  '2021-10-29': {'1. open': '141.0000',
#   '2. high': '146.0000',
#   '3. low': '124.6200',
#   '4. close': '125.1000',
#   '5. adjusted close': '101.2007',
#   '6. volume': '144097758',
#   '7. dividend amount': '0.0000'},
#  '2021-09-30': {'1. open': '139.9800',
#   '2. high': '140.5700',
#   '3. low': '132.7800',
#   '4. close': '138.9300',
#   '5. adjusted close': '112.3886',
#   '6. volume': '76644238',
#   '7. dividend amount': '0.0000'},
#  '2021-08-31': {'1. open': '141.4500',
#   '2. high': '144.7000',
#   '3. low': '137.2100',
#   '4. close': '140.3400',
#   '5. adjusted close': '113.5293',
#   '6. volume': '69687056',
#   '7. dividend amount': '1.6400'},
#  '2021-07-30': {'1. open': '146.9600',
#   '2. high': '147.5000',
#   '3. low': '136.2089',
#   '4. close': '140.9600',
#   '5. adjusted close': '112.7220',
#   '6. volume': '110625907',
#   '7. dividend amount': '0.0000'},
#  '2021-06-30': {'1. open': '145.0000',
#   '2. high': '152.8400',
#   '3. low': '143.0400',
#   '4. close': '146.5900',
#   '5. adjusted close': '117.2242',
#   '6. volume': '84365220',
#   '7. dividend amount': '0.0000'},
#  '2021-05-28': {'1. open': '143.8100',
#   '2. high': '148.5150',
#   '3. low': '140.9200',
#   '4. close': '143.7400',
#   '5. adjusted close': '114.9451',
#   '6. volume': '98036425',
#   '7. dividend amount': '1.6400'},
#  '2021-04-30': {'1. open': '133.7600',
#   '2. high': '148.7400',
#   '3. low': '130.3800',
#   '4. close': '141.8800',
#   '5. adjusted close': '112.1928',
#   '6. volume': '122920494',
#   '7. dividend amount': '0.0000'},
#  '2021-03-31': {'1. open': '120.3500',
#   '2. high': '137.0700',
#   '3. low': '118.7550',
#   '4. close': '133.2600',
#   '5. adjusted close': '105.3765',
#   '6. volume': '127967821',
#   '7. dividend amount': '0.0000'},
#  '2021-02-26': {'1. open': '119.9000',
#   '2. high': '124.3500',
#   '3. low': '118.1200',
#   '4. close': '118.9300',
#   '5. adjusted close': '94.0449',
#   '6. volume': '106339228',
#   '7. dividend amount': '1.6300'},
#  '2021-01-29': {'1. open': '125.8500',
#   '2. high': '132.2400',
#   '3. low': '117.3600',
#   '4. close': '119.1100',
#   '5. adjusted close': '92.9464',
#   '6. volume': '176168962',
#   '7. dividend amount': '0.0000'},
#  '2020-12-31': {'1. open': '123.9000',
#   '2. high': '127.6900',
#   '3. low': '121.7200',
#   '4. close': '125.8800',
#   '5. adjusted close': '98.2293',
#   '6. volume': '102587006',
#   '7. dividend amount': '0.0000'},
#  '2020-11-30': {'1. open': '112.6500',
#   '2. high': '125.3130',
#   '3. low': '111.1600',
#   '4. close': '123.5200',
#   '5. adjusted close': '96.3877',
#   '6. volume': '103461100',
#   '7. dividend amount': '1.6300'},
#  '2020-10-30': {'1. open': '122.3600',
#   '2. high': '135.5000',
#   '3. low': '105.9200',
#   '4. close': '111.6600',
#   '5. adjusted close': '85.9206',
#   '6. volume': '159130911',
#   '7. dividend amount': '0.0000'},
#  '2020-09-30': {'1. open': '122.8500',
#   '2. high': '129.9500',
#   '3. low': '116.4800',
#   '4. close': '121.6700',
#   '5. adjusted close': '93.6232',
#   '6. volume': '84510174',
#   '7. dividend amount': '0.0000'},
#  '2020-08-31': {'1. open': '123.5000',
#   '2. high': '130.4700',
#   '3. low': '122.1500',
#   '4. close': '123.3100',
#   '5. adjusted close': '94.8851',
#   '6. volume': '74033007',
#   '7. dividend amount': '1.6300'},
#  '2020-07-31': {'1. open': '120.2700',
#   '2. high': '132.1700',
#   '3. low': '115.2000',
#   '4. close': '122.9400',
#   '5. adjusted close': '93.3823',
#   '6. volume': '113972765',
#   '7. dividend amount': '0.0000'},
#  '2020-06-30': {'1. open': '124.6400',
#   '2. high': '135.8800',
#   '3. low': '115.8800',
#   '4. close': '120.7700',
#   '5. adjusted close': '91.7341',
#   '6. volume': '120931250',
#   '7. dividend amount': '0.0000'},
#  '2020-05-29': {'1. open': '123.1900',
#   '2. high': '126.9700',
#   '3. low': '111.8100',
#   '4. close': '124.9000',
#   '5. adjusted close': '94.8711',
#   '6. volume': '92864791',
#   '7. dividend amount': '1.6300'},
#  '2020-04-30': {'1. open': '106.3600',
#   '2. high': '129.3100',
#   '3. low': '104.5200',
#   '4. close': '125.5600',
#   '5. adjusted close': '94.1071',
#   '6. volume': '130400316',
#   '7. dividend amount': '0.0000'},
#  '2020-03-31': {'1. open': '130.7500',
#   '2. high': '136.1000',
#   '3. low': '90.5600',
#   '4. close': '110.9300',
#   '5. adjusted close': '83.1419',
#   '6. volume': '189585053',
#   '7. dividend amount': '0.0000'},
#  '2020-02-28': {'1. open': '144.2500',
#   '2. high': '158.7500',
#   '3. low': '126.3600',
#   '4. close': '130.1500',
#   '5. adjusted close': '97.5473',
#   '6. volume': '118092333',
#   '7. dividend amount': '1.6200'},
#  '2020-01-31': {'1. open': '135.0000',
#   '2. high': '145.7900',
#   '3. low': '133.2000',
#   '4. close': '143.7300',
#   '5. adjusted close': '106.5998',
#   '6. volume': '112864967',
#   '7. dividend amount': '0.0000'},
#  '2019-12-31': {'1. open': '134.4500',
#   '2. high': '136.4200',
#   '3. low': '130.6900',
#   '4. close': '134.0400',
#   '5. adjusted close': '99.4131',
#   '6. volume': '71661951',
#   '7. dividend amount': '0.0000'},
#  '2019-11-29': {'1. open': '134.5000',
#   '2. high': '139.1400',
#   '3. low': '132.7500',
#   '4. close': '134.4500',
#   '5. adjusted close': '99.7171',
#   '6. volume': '64898948',
#   '7. dividend amount': '1.6200'},
#  '2019-10-31': {'1. open': '145.5900',
#   '2. high': '147.3500',
#   '3. low': '130.9000',
#   '4. close': '133.7300',
#   '5. adjusted close': '98.0298',
#   '6. volume': '92647927',
#   '7. dividend amount': '0.0000'},
#  '2019-09-30': {'1. open': '134.8500',
#   '2. high': '146.5700',
#   '3. low': '133.3300',
#   '4. close': '145.4200',
#   '5. adjusted close': '106.5990',
#   '6. volume': '62083780',
#   '7. dividend amount': '0.0000'},
#  '2019-08-30': {'1. open': '148.9000',
#   '2. high': '152.9500',
#   '3. low': '128.8300',
#   '4. close': '135.5300',
#   '5. adjusted close': '99.3492',
#   '6. volume': '96719129',
#   '7. dividend amount': '1.6200'},
#  '2019-07-31': {'1. open': '139.6000',
#   '2. high': '151.9400',
#   '3. low': '139.1300',
#   '4. close': '148.2400',
#   '5. adjusted close': '107.4241',
#   '6. volume': '80175943',
#   '7. dividend amount': '0.0000'},
#  '2019-06-28': {'1. open': '127.1000',
#   '2. high': '140.1500',
#   '3. low': '127.0600',
#   '4. close': '137.9000',
#   '5. adjusted close': '99.9310',
#   '6. volume': '61342985',
#   '7. dividend amount': '0.0000'},
#  '2019-05-31': {'1. open': '140.5500',
#   '2. high': '141.8100',
#   '3. low': '126.8500',
#   '4. close': '126.9900',
#   '5. adjusted close': '92.0250',
#   '6. volume': '75537897',
#   '7. dividend amount': '1.6200'},
#  '2019-04-30': {'1. open': '141.5100',
#   '2. high': '145.3900',
#   '3. low': '136.2600',
#   '4. close': '140.2700',
#   '5. adjusted close': '100.4462',
#   '6. volume': '80199229',
#   '7. dividend amount': '0.0000'},
#  '2019-03-29': {'1. open': '139.3100',
#   '2. high': '142.1200',
#   '3. low': '133.5800',
#   '4. close': '141.1000',
#   '5. adjusted close': '101.0405',
#   '6. volume': '74688899',
#   '7. dividend amount': '0.0000'},
#  '2019-02-28': {'1. open': '134.9700',
#   '2. high': '140.4900',
#   '3. low': '132.1200',
#   '4. close': '138.1300',
#   '5. adjusted close': '98.9137',
#   '6. volume': '68462024',
#   '7. dividend amount': '1.5700'},
#  '2019-01-31': {'1. open': '112.0100',
#   '2. high': '135.4100',
#   '3. low': '111.6900',
#   '4. close': '134.4200',
#   '5. adjusted close': '95.1356',
#   '6. volume': '120388583',
#   '7. dividend amount': '0.0000'},
#  '2018-12-31': {'1. open': '125.6700',
#   '2. high': '126.5900',
#   '3. low': '105.9400',
#   '4. close': '113.6700',
#   '5. adjusted close': '80.4498',
#   '6. volume': '115600988',
#   '7. dividend amount': '0.0000'},
#  '2018-11-30': {'1. open': '115.5000',
#   '2. high': '125.0600',
#   '3. low': '114.5400',
#   '4. close': '124.2700',
#   '5. adjusted close': '87.9520',
#   '6. volume': '141719180',
#   '7. dividend amount': '1.5700'},
#  '2018-10-31': {'1. open': '151.7100',
#   '2. high': '154.3600',
#   '3. low': '114.0900',
#   '4. close': '115.4300',
#   '5. adjusted close': '80.6689',
#   '6. volume': '198093801',
#   '7. dividend amount': '0.0000'},
#  '2018-09-28': {'1. open': '145.9800',
#   '2. high': '153.3500',
#   '3. low': '144.8100',
#   '4. close': '151.2100',
#   '5. adjusted close': '105.6740',
#   '6. volume': '95868702',
#   '7. dividend amount': '0.0000'},
#  '2018-08-31': {'1. open': '144.7600',
#   '2. high': '147.9300',
#   '3. low': '142.0000',
#   '4. close': '146.4800',
#   '5. adjusted close': '102.3684',
#   '6. volume': '79196876',
#   '7. dividend amount': '1.5700'},
#  '2018-07-31': {'1. open': '138.2800',
#   '2. high': '150.5400',
#   '3. low': '138.2000',
#   '4. close': '144.9300',
#   '5. adjusted close': '100.1986',
#   '6. volume': '95015127',
#   '7. dividend amount': '0.0000'},
#  '2018-06-29': {'1. open': '142.4300',
#   '2. high': '147.5200',
#   '3. low': '137.4500',
#   '4. close': '139.7000',
#   '5. adjusted close': '96.5828',
#   '6. volume': '90243111',
#   '7. dividend amount': '0.0000'},
#  '2018-05-31': {'1. open': '144.6500',
#   '2. high': '146.2000',
#   '3. low': '139.9000',
#   '4. close': '141.3100',
#   '5. adjusted close': '97.6958',
#   '6. volume': '88812832',
#   '7. dividend amount': '1.5700'},
#  '2018-04-30': {'1. open': '153.3400',
#   '2. high': '162.0000',
#   '3. low': '144.1100',
#   '4. close': '144.9600',
#   '5. adjusted close': '99.1280',
#   '6. volume': '122893135',
#   '7. dividend amount': '0.0000'},
#  '2018-03-29': {'1. open': '155.5300',
#   '2. high': '162.1100',
#   '3. low': '148.5400',
#   '4. close': '153.4300',
#   '5. adjusted close': '104.9200',
#   '6. volume': '92113147',
#   '7. dividend amount': '0.0000'},
#  '2018-02-28': {'1. open': '163.1900',
#   '2. high': '164.1300',
#   '3. low': '144.4000',
#   '4. close': '155.8300',
#   '5. adjusted close': '106.5612',
#   '6. volume': '100673819',
#   '7. dividend amount': '1.5000'},
#  '2018-01-31': {'1. open': '154.5000',
#   '2. high': '171.1300',
#   '3. low': '153.5400',
#   '4. close': '163.7000',
#   '5. adjusted close': '110.8167',
#   '6. volume': '140197975',
#   '7. dividend amount': '0.0000'},
#  '2017-12-29': {'1. open': '154.4000',
#   '2. high': '157.8500',
#   '3. low': '151.4900',
#   '4. close': '153.4200',
#   '5. adjusted close': '103.8577',
#   '6. volume': '87525752',
#   '7. dividend amount': '0.0000'},
#  '2017-11-30': {'1. open': '154.1000',
#   '2. high': '154.9000',
#   '3. low': '146.2110',
#   '4. close': '153.9700',
#   '5. adjusted close': '104.2300',
#   '6. volume': '89208545',
#   '7. dividend amount': '1.5000'},
#  '2017-10-31': {'1. open': '145.3500',
#   '2. high': '162.5100',
#   '3. low': '145.2100',
#   '4. close': '154.0600',
#   '5. adjusted close': '103.2604',
#   '6. volume': '121490046',
#   '7. dividend amount': '0.0000'},
#  '2017-09-29': {'1. open': '142.9800',
#   '2. high': '147.4200',
#   '3. low': '141.6400',
#   '4. close': '145.0800',
#   '5. adjusted close': '97.2414',
#   '6. volume': '77056229',
#   '7. dividend amount': '0.0000'},
#  '2017-08-31': {'1. open': '145.0000',
#   '2. high': '145.6700',
#   '3. low': '139.1300',
#   '4. close': '143.0300',
#   '5. adjusted close': '95.8674',
#   '6. volume': '79260314',
#   '7. dividend amount': '1.5000'},
#  '2017-07-31': {'1. open': '153.5800',
#   '2. high': '156.0250',
#   '3. low': '143.6400',
#   '4. close': '144.6700',
#   '5. adjusted close': '95.9538',
#   '6. volume': '91242021',
#   '7. dividend amount': '0.0000'},
#  '2017-06-30': {'1. open': '152.8000',
#   '2. high': '157.2000',
#   '3. low': '150.8000',
#   '4. close': '153.8300',
#   '5. adjusted close': '102.0293',
#   '6. volume': '82652760',
#   '7. dividend amount': '0.0000'},
#  '2017-05-31': {'1. open': '160.0500',
#   '2. high': '160.4200',
#   '3. low': '149.7900',
#   '4. close': '152.6300',
#   '5. adjusted close': '101.2334',
#   '6. volume': '102455942',
#   '7. dividend amount': '1.5000'},
#  '2017-04-28': {'1. open': '173.8200',
#   '2. high': '176.3300',
#   '3. low': '159.6000',
#   '4. close': '160.2900',
#   '5. adjusted close': '105.2820',
#   '6. volume': '99850446',
#   '7. dividend amount': '0.0000'},
#  '2017-03-31': {'1. open': '180.4800',
#   '2. high': '182.5500',
#   '3. low': '172.0937',
#   '4. close': '174.1400',
#   '5. adjusted close': '114.3789',
#   '6. volume': '79476385',
#   '7. dividend amount': '0.0000'},
#  '2017-02-28': {'1. open': '175.0000',
#   '2. high': '182.7900',
#   '3. low': '172.8900',
#   '4. close': '179.8200',
#   '5. adjusted close': '118.1097',
#   '6. volume': '59817600',
#   '7. dividend amount': '1.4000'},
#  '2017-01-31': {'1. open': '167.0000',
#   '2. high': '179.2500',
#   '3. low': '165.3400',
#   '4. close': '174.5200',
#   '5. adjusted close': '113.7248',
#   '6. volume': '88671370',
#   '7. dividend amount': '0.0000'},
#  '2016-12-30': {'1. open': '161.9500',
#   '2. high': '169.9520',
#   '3. low': '158.3000',
#   '4. close': '165.9900',
#   '5. adjusted close': '108.1663',
#   '6. volume': '69463793',
#   '7. dividend amount': '0.0000'},
#  '2016-11-30': {'1. open': '153.5000',
#   '2. high': '164.6600',
#   '3. low': '151.0000',
#   '4. close': '162.2200',
#   '5. adjusted close': '105.7096',
#   '6. volume': '76340912',
#   '7. dividend amount': '1.4000'},
#  '2016-10-31': {'1. open': '158.0600',
#   '2. high': '158.5300',
#   '3. low': '147.7900',
#   '4. close': '153.6900',
#   '5. adjusted close': '99.2555',
#   '6. volume': '78325840',
#   '7. dividend amount': '0.0000'},
#  '2016-09-30': {'1. open': '158.3200',
#   '2. high': '165.0000',
#   '3. low': '153.2100',
#   '4. close': '158.8500',
#   '5. adjusted close': '102.5879',
#   '6. volume': '69951563',
#   '7. dividend amount': '0.0000'},
#  '2016-08-31': {'1. open': '160.6500',
#   '2. high': '164.9500',
#   '3. low': '157.8500',
#   '4. close': '158.8800',
#   '5. adjusted close': '102.6073',
#   '6. volume': '69680582',
#   '7. dividend amount': '1.4000'},
#  '2016-07-29': {'1. open': '152.1900',
#   '2. high': '163.6000',
#   '3. low': '149.9200',
#   '4. close': '160.6200',
#   '5. adjusted close': '102.8425',
#   '6. volume': '69930927',
#   '7. dividend amount': '0.0000'},
#  '2016-06-30': {'1. open': '153.0000',
#   '2. high': '155.4800',
#   '3. low': '142.5000',
#   '4. close': '151.7800',
#   '5. adjusted close': '97.1824',
#   '6. volume': '77115961',
#   '7. dividend amount': '0.0000'},
#  '2016-05-31': {'1. open': '146.5600',
#   '2. high': '153.8100',
#   '3. low': '142.9000',
#   '4. close': '153.7400',
#   '5. adjusted close': '98.4373',
#   '6. volume': '75248178',
#   '7. dividend amount': '1.4000'},
#  '2016-04-29': {'1. open': '150.5100',
#   '2. high': '153.5200',
#   '3. low': '142.6100',
#   '4. close': '145.9400',
#   '5. adjusted close': '92.5633',
#   '6. volume': '94431134',
#   '7. dividend amount': '0.0000'},
#  '2016-03-31': {'1. open': '132.2400',
#   '2. high': '153.1000',
#   '3. low': '132.0300',
#   '4. close': '151.4500',
#   '5. adjusted close': '96.0580',
#   '6. volume': '105698603',
#   '7. dividend amount': '0.0000'},
#  '2016-02-29': {'1. open': '124.4000',
#   '2. high': '134.9200',
#   '3. low': '116.9010',
#   '4. close': '131.0300',
#   '5. adjusted close': '83.1065',
#   '6. volume': '106703104',
#   '7. dividend amount': '1.3000'},
#  '2016-01-29': {'1. open': '135.6000',
#   '2. high': '136.8900',
#   '3. low': '118.0000',
#   '4. close': '124.7900',
#   '5. adjusted close': '78.3467',
#   '6. volume': '126204196',
#   '7. dividend amount': '0.0000'},
#  '2015-12-31': {'1. open': '139.5800',
#   '2. high': '141.4000',
#   '3. low': '133.9100',
#   '4. close': '137.6200',
#   '5. adjusted close': '86.4017',
#   '6. volume': '97650594',
#   '7. dividend amount': '0.0000'},
#  '2015-11-30': {'1. open': '140.5000',
#   '2. high': '142.8000',
#   '3. low': '131.6500',
#   '4. close': '139.4200',
#   '5. adjusted close': '87.5318',
#   '6. volume': '85421426',
#   '7. dividend amount': '1.3000'},
#  '2015-10-30': {'1. open': '145.3100',
#   '2. high': '153.1470',
#   '3. low': '137.3300',
#   '4. close': '140.0800',
#   '5. adjusted close': '87.1269',
#   '6. volume': '120622363',
#   '7. dividend amount': '0.0000'},
#  '2015-09-30': {'1. open': '144.8400',
#   '2. high': '149.6800',
#   '3. low': '141.1501',
#   '4. close': '144.9700',
#   '5. adjusted close': '90.1684',
#   '6. volume': '81761648',
#   '7. dividend amount': '0.0000'},
#  '2015-08-31': {'1. open': '161.7000',
#   '2. high': '161.8500',
#   '3. low': '140.6200',
#   '4. close': '147.8900',
#   '5. adjusted close': '91.9846',
#   '6. volume': '93750967',
#   '7. dividend amount': '1.3000'},
#  '2015-07-31': {'1. open': '163.9700',
#   '2. high': '173.7800',
#   '3. low': '158.5000',
#   '4. close': '161.9900',
#   '5. adjusted close': '99.9235',
#   '6. volume': '93805392',
#   '7. dividend amount': '0.0000'},
#  '2015-06-30': {'1. open': '170.2100',
#   '2. high': '171.5601',
#   '3. low': '162.1200',
#   '4. close': '162.6600',
#   '5. adjusted close': '100.3368',
#   '6. volume': '80845501',
#   '7. dividend amount': '0.0000'},
#  '2015-05-29': {'1. open': '173.2000',
#   '2. high': '176.3000',
#   '3. low': '168.8400',
#   '4. close': '169.6500',
#   '5. adjusted close': '104.6486',
#   '6. volume': '57916093',
#   '7. dividend amount': '1.3000'},
#  '2015-04-30': {'1. open': '160.2300',
#   '2. high': '175.1303',
#   '3. low': '158.3900',
#   '4. close': '171.2900',
#   '5. adjusted close': '104.8586',
#   '6. volume': '93821213',
#   '7. dividend amount': '0.0000'},
#  '2015-03-31': {'1. open': '161.6800',
#   '2. high': '165.3500',
#   '3. low': '153.4000',
#   '4. close': '160.5000',
#   '5. adjusted close': '98.2533',
#   '6. volume': '104899758',
#   '7. dividend amount': '0.0000'},
#  '2015-02-27': {'1. open': '154.0000',
#   '2. high': '164.9900',
#   '3. low': '151.5100',
#   '4. close': '161.9400',
#   '5. adjusted close': '99.1348',
#   '6. volume': '77654705',
#   '7. dividend amount': '1.1000'},
#  '2015-01-30': {'1. open': '161.3100',
#   '2. high': '163.3100',
#   '3. low': '149.5200',
#   '4. close': '153.3100',
#   '5. adjusted close': '93.1976',
#   '6. volume': '117395861',
#   '7. dividend amount': '0.0000'},
#  '2014-12-31': {'1. open': '161.6400',
#   '2. high': '164.5200',
#   '3. low': '150.5000',
#   '4. close': '160.4400',
#   '5. adjusted close': '97.5320',
#   '6. volume': '101614529',
#   '7. dividend amount': '0.0000'},
#  '2014-11-28': {'1. open': '164.2500',
#   '2. high': '164.9700',
#   '3. low': '159.8000',
#   '4. close': '162.1700',
#   '5. adjusted close': '98.5836',
#   '6. volume': '80018581',
#   '7. dividend amount': '1.1000'},
#  '2014-10-31': {'1. open': '189.9100',
#   '2. high': '190.8900',
#   '3. low': '161.1000',
#   '4. close': '164.4000',
#   '5. adjusted close': '99.2630',
#   '6. volume': '146272610',
#   '7. dividend amount': '0.0000'},
#  '2014-09-30': {'1. open': '192.6800',
#   '2. high': '195.0000',
#   '3. low': '188.1200',
#   '4. close': '189.8300',
#   '5. adjusted close': '114.6174',
#   '6. volume': '64033759',
#   '7. dividend amount': '0.0000'},
#  '2014-08-29': {'1. open': '190.5000',
#   '2. high': '194.1330',
#   '3. low': '183.5800',
#   '4. close': '192.3000',
#   '5. adjusted close': '116.1087',
#   '6. volume': '53441600',
#   '7. dividend amount': '1.1000'},
#  '2014-07-31': {'1. open': '181.7000',
#   '2. high': '196.4000',
#   '3. low': '181.7000',
#   '4. close': '191.6700',
#   '5. adjusted close': '115.0478',
#   '6. volume': '97597800',
#   '7. dividend amount': '0.0000'},
#  '2014-06-30': {'1. open': '184.7600',
#   '2. high': '187.6500',
#   '3. low': '179.2700',
#   '4. close': '181.2700',
#   '5. adjusted close': '108.8053',
#   '6. volume': '78501700',
#   '7. dividend amount': '0.0000'},
#  '2014-05-30': {'1. open': '196.3100',
#   '2. high': '196.7400',
#   '3. low': '182.3300',
#   '4. close': '184.3600',
#   '5. adjusted close': '110.6601',
#   '6. volume': '70018300',
#   '7. dividend amount': '1.1000'},
#  '2014-04-30': {'1. open': '193.1200',
#   '2. high': '199.2100',
#   '3. low': '187.0100',
#   '4. close': '196.4700',
#   '5. adjusted close': '117.2477',
#   '6. volume': '118447100',
#   '7. dividend amount': '0.0000'},
#  '2014-03-31': {'1. open': '183.3300',
#   '2. high': '195.6300',
#   '3. low': '182.2100',
#   '4. close': '192.4900',
#   '5. adjusted close': '114.8725',
#   '6. volume': '118984000',
#   '7. dividend amount': '0.0000'},
#  '2014-02-28': {'1. open': '176.0200',
#   '2. high': '186.1200',
#   '3. low': '172.1900',
#   '4. close': '185.1700',
#   '5. adjusted close': '110.5041',
#   '6. volume': '87054800',
#   '7. dividend amount': '0.9500'},
#  '2014-01-31': {'1. open': '187.2100',
#   '2. high': '190.8100',
#   '3. low': '175.3400',
#   '4. close': '176.6800',
#   '5. adjusted close': '104.8672',
#   '6. volume': '123489300',
#   '7. dividend amount': '0.0000'},
#  '2013-12-31': {'1. open': '179.4600',
#   '2. high': '187.7900',
#   '3. low': '172.7300',
#   '4. close': '187.5700',
#   '5. adjusted close': '111.3309',
#   '6. volume': '97993100',
#   '7. dividend amount': '0.0000'},
#  '2013-11-29': {'1. open': '179.8100',
#   '2. high': '186.2400',
#   '3. low': '177.3100',
#   '4. close': '179.6800',
#   '5. adjusted close': '106.6478',
#   '6. volume': '100984900',
#   '7. dividend amount': '0.9500'},
#  '2013-10-31': {'1. open': '185.3400',
#   '2. high': '186.9900',
#   '3. low': '172.5700',
#   '4. close': '179.2100',
#   '5. adjusted close': '105.8079',
#   '6. volume': '130967100',
#   '7. dividend amount': '0.0000'},
#  '2013-09-30': {'1. open': '183.6300',
#   '2. high': '194.8900',
#   '3. low': '182.3100',
#   '4. close': '185.1800',
#   '5. adjusted close': '109.3327',
#   '6. volume': '71488100',
#   '7. dividend amount': '0.0000'},
#  '2013-08-30': {'1. open': '196.6500',
#   '2. high': '197.1700',
#   '3. low': '181.1000',
#   '4. close': '182.2700',
#   '5. adjusted close': '107.6146',
#   '6. volume': '73077400',
#   '7. dividend amount': '0.9500'},
#  '2013-07-31': {'1. open': '192.1500',
#   '2. high': '200.9400',
#   '3. low': '190.2600',
#   '4. close': '195.0400',
#   '5. adjusted close': '114.5769',
#   '6. volume': '88079400',
#   '7. dividend amount': '0.0000'},
#  '2013-06-28': {'1. open': '208.2500',
#   '2. high': '210.0500',
#   '3. low': '188.4100',
#   '4. close': '191.1100',
#   '5. adjusted close': '112.2682',
#   '6. volume': '80215000',
#   '7. dividend amount': '0.0000'},
#  '2013-05-31': {'1. open': '201.8700',
#   '2. high': '211.9800',
#   '3. low': '199.2000',
#   '4. close': '208.0200',
#   '5. adjusted close': '122.2020',
#   '6. volume': '90683600',
#   '7. dividend amount': '0.9500'},
#  '2013-04-30': {'1. open': '212.8000',
#   '2. high': '214.8900',
#   '3. low': '187.6800',
#   '4. close': '202.5400',
#   '5. adjusted close': '118.4335',
#   '6. volume': '108666600',
#   '7. dividend amount': '0.0000'},
#  '2013-03-28': {'1. open': '200.6500',
#   '2. high': '215.9000',
#   '3. low': '199.3600',
#   '4. close': '213.3000',
#   '5. adjusted close': '124.7253',
#   '6. volume': '76023800',
#   '7. dividend amount': '0.0000'},
#  '2013-02-28': {'1. open': '204.6500',
#   '2. high': '205.3500',
#   '3. low': '197.5100',
#   '4. close': '200.8300',
#   '5. adjusted close': '117.4336',
#   '6. volume': '64144100',
#   '7. dividend amount': '0.8500'},
#  '2013-01-31': {'1. open': '194.0900',
#   '2. high': '208.5800',
#   '3. low': '190.3900',
#   '4. close': '203.0700',
#   '5. adjusted close': '118.2434',
#   '6. volume': '87636600',
#   '7. dividend amount': '0.0000'},
#  '2012-12-31': {'1. open': '190.7600',
#   '2. high': '196.4500',
#   '3. low': '186.9400',
#   '4. close': '191.5500',
#   '5. adjusted close': '111.5355',
#   '6. volume': '79320200',
#   '7. dividend amount': '0.0000'},
#  '2012-11-30': {'1. open': '194.9600',
#   '2. high': '198.0000',
#   '3. low': '184.7800',
#   '4. close': '190.0700',
#   '5. adjusted close': '110.6738',
#   '6. volume': '81892500',
#   '7. dividend amount': '0.8500'},
#  '2012-10-31': {'1. open': '208.0100',
#   '2. high': '211.7900',
#   '3. low': '190.5600',
#   '4. close': '194.5300',
#   '5. adjusted close': '112.7693',
#   '6. volume': '96155000',
#   '7. dividend amount': '0.0000'},
#  '2012-09-28': {'1. open': '196.6100',
#   '2. high': '208.3200',
#   '3. low': '193.2500',
#   '4. close': '207.4500',
#   '5. adjusted close': '120.2590',
#   '6. volume': '77341400',
#   '7. dividend amount': '0.0000'},
#  '2012-08-31': {'1. open': '196.9600',
#   '2. high': '202.0000',
#   '3. low': '193.0200',
#   '4. close': '194.8500',
#   '5. adjusted close': '112.9548',
#   '6. volume': '60653700',
#   '7. dividend amount': '0.8500'},
#  '2012-07-31': {'1. open': '196.3600',
#   '2. high': '197.8400',
#   '3. low': '181.8500',
#   '4. close': '195.9800',
#   '5. adjusted close': '113.1267',
#   '6. volume': '91516500',
#   '7. dividend amount': '0.0000'},
#  '2012-06-29': {'1. open': '190.1200',
#   '2. high': '199.9900',
#   '3. low': '187.0000',
#   '4. close': '195.5800',
#   '5. adjusted close': '112.8958',
#   '6. volume': '84559100',
#   '7. dividend amount': '0.0000'},
#  '2012-05-31': {'1. open': '207.1800',
#   '2. high': '208.9290',
#   '3. low': '192.0000',
#   '4. close': '192.9000',
#   '5. adjusted close': '111.3489',
#   '6. volume': '86005300',
#   '7. dividend amount': '0.8500'},
#  '2012-04-30': {'1. open': '208.9600',
#   '2. high': '210.6900',
#   '3. low': '196.7910',
#   '4. close': '207.0800',
#   '5. adjusted close': '119.0319',
#   '6. volume': '86603000',
#   '7. dividend amount': '0.0000'},
#  '2012-03-30': {'1. open': '197.2300',
#   '2. high': '209.1200',
#   '3. low': '196.8120',
#   '4. close': '208.6500',
#   '5. adjusted close': '119.9343',
#   '6. volume': '88096900',
#   '7. dividend amount': '0.0000'},
#  '2012-02-29': {'1. open': '193.2100',
#   '2. high': '199.2300',
#   '3. low': '190.8310',
#   '4. close': '196.7300',
#   '5. adjusted close': '113.0826',
#   '6. volume': '78809900',
#   '7. dividend amount': '0.7500'},
#  '2012-01-31': {'1. open': '186.7300',
#   '2. high': '193.1000',
#   '3. low': '177.3472',
#   '4. close': '192.6000',
#   '5. adjusted close': '110.2800',
#   '6. volume': '110015000',
#   '7. dividend amount': '0.0000'},
#  '2011-12-30': {'1. open': '187.0100',
#   '2. high': '194.9000',
#   '3. low': '179.0400',
#   '4. close': '183.8800',
#   '5. adjusted close': '105.2870',
#   '6. volume': '103436500',
#   '7. dividend amount': '0.0000'},
#  '2011-11-30': {'1. open': '181.5500',
#   '2. high': '189.9700',
#   '3. low': '177.0600',
#   '4. close': '188.0000',
#   '5. adjusted close': '107.6461',
#   '6. volume': '97014100',
#   '7. dividend amount': '0.7500'},
#  '2011-10-31': {'1. open': '174.3600',
#   '2. high': '190.5300',
#   '3. low': '168.8800',
#   '4. close': '184.6300',
#   '5. adjusted close': '105.2947',
#   '6. volume': '144563700',
#   '7. dividend amount': '0.0000'},
#  '2011-09-30': {'1. open': '172.7100',
#   '2. high': '180.9100',
#   '3. low': '158.7600',
#   '4. close': '174.8700',
#   '5. adjusted close': '99.7286',
#   '6. volume': '137895000',
#   '7. dividend amount': '0.0000'},
#  '2011-08-31': {'1. open': '182.6000',
#   '2. high': '183.6900',
#   '3. low': '157.1300',
#   '4. close': '171.9100',
#   '5. adjusted close': '98.0405',
#   '6. volume': '195054100',
#   '7. dividend amount': '0.7500'},
#  '2011-07-29': {'1. open': '171.6100',
#   '2. high': '185.6300',
#   '3. low': '171.4900',
#   '4. close': '181.8500',
#   '5. adjusted close': '103.2434',
#   '6. volume': '113593200',
#   '7. dividend amount': '0.0000'},
#  '2011-06-30': {'1. open': '168.9000',
#   '2. high': '172.4468',
#   '3. low': '161.5200',
#   '4. close': '171.5500',
#   '5. adjusted close': '97.3957',
#   '6. volume': '105442400',
#   '7. dividend amount': '0.0000'},
#  '2011-05-31': {'1. open': '172.1100',
#   '2. high': '173.5400',
#   '3. low': '165.9000',
#   '4. close': '168.9300',
#   '5. adjusted close': '95.9082',
#   '6. volume': '110804200',
#   '7. dividend amount': '0.7500'},
#  '2011-04-29': {'1. open': '163.7000',
#   '2. high': '173.0000',
#   '3. low': '162.1900',
#   '4. close': '170.5800',
#   '5. adjusted close': '96.4168',
#   '6. volume': '100769500',
#   '7. dividend amount': '0.0000'},
#  '2011-03-31': {'1. open': '163.1500',
#   '2. high': '167.7200',
#   '3. low': '151.7100',
#   '4. close': '163.0700',
#   '5. adjusted close': '92.1720',
#   '6. volume': '129714300',
#   '7. dividend amount': '0.0000'},
#  '2011-02-28': {'1. open': '162.1100',
#   '2. high': '166.2500',
#   '3. low': '159.0300',
#   '4. close': '161.8800',
#   '5. adjusted close': '91.4994',
#   '6. volume': '89067500',
#   '7. dividend amount': '0.6500'},
#  '2011-01-31': {'1. open': '147.2100',
#   '2. high': '164.3500',
#   '3. low': '146.6400',
#   '4. close': '162.0000',
#   '5. adjusted close': '91.2101',
#   '6. volume': '118831600',
#   '7. dividend amount': '0.0000'},
#  '2010-12-31': {'1. open': '143.6100',
#   '2. high': '147.5000',
#   '3. low': '143.5100',
#   '4. close': '146.7600',
#   '5. adjusted close': '82.6296',
#   '6. volume': '93392800',
#   '7. dividend amount': '0.0000'},
#  '2010-11-30': {'1. open': '143.6400',
#   '2. high': '147.5300',
#   '3. low': '141.1800',
#   '4. close': '141.4600',
#   '5. adjusted close': '79.6456',
#   '6. volume': '104096700',
#   '7. dividend amount': '0.6500'},
#  '2010-10-29': {'1. open': '135.5100',
#   '2. high': '144.0000',
#   '3. low': '134.3900',
#   '4. close': '143.6000',
#   '5. adjusted close': '80.4932',
#   '6. volume': '137284700',
#   '7. dividend amount': '0.0000'},
#  '2010-09-30': {'1. open': '125.3100',
#   '2. high': '136.1100',
#   '3. low': '124.5200',
#   '4. close': '134.1400',
#   '5. adjusted close': '75.1905',
#   '6. volume': '116092900',
#   '7. dividend amount': '0.0000'},
#  '2010-08-31': {'1. open': '129.2500',
#   '2. high': '132.4900',
#   '3. low': '122.2800',
#   '4. close': '123.1300',
#   '5. adjusted close': '69.0190',
#   '6. volume': '117394000',
#   '7. dividend amount': '0.6500'},
#  '2010-07-30': {'1. open': '123.5500',
#   '2. high': '131.6000',
#   '3. low': '120.6100',
#   '4. close': '128.4000',
#   '5. adjusted close': '71.6154',
#   '6. volume': '144080000',
#   '7. dividend amount': '0.0000'},
#  '2010-06-30': {'1. open': '124.6900',
#   '2. high': '131.9400',
#   '3. low': '122.8200',
#   '4. close': '123.4800',
#   '5. adjusted close': '68.8712',
#   '6. volume': '162019100',
#   '7. dividend amount': '0.0000'},
#  '2010-05-28': {'1. open': '129.3900',
#   '2. high': '133.1000',
#   '3. low': '116.0000',
#   '4. close': '125.2600',
#   '5. adjusted close': '69.8640',
#   '6. volume': '188444200',
#   '7. dividend amount': '0.6500'},
#  '2010-04-30': {'1. open': '128.9500',
#   '2. high': '132.2800',
#   '3. low': '127.1200',
#   '4. close': '129.0000',
#   '5. adjusted close': '71.5746',
#   '6. volume': '146426400',
#   '7. dividend amount': '0.0000'},
#  '2010-03-31': {'1. open': '127.5000',
#   '2. high': '130.7300',
#   '3. low': '125.2000',
#   '4. close': '128.2500',
#   '5. adjusted close': '71.1585',
#   '6. volume': '139997300',
#   '7. dividend amount': '0.0000'},
#  '2010-02-26': {'1. open': '123.2300',
#   '2. high': '128.2700',
#   '3. low': '121.6100',
#   '4. close': '127.1600',
#   '5. adjusted close': '70.5537',
#   '6. volume': '113211200',
#   '7. dividend amount': '0.5500'},
#  '2010-01-29': {'1. open': '131.1800',
#   '2. high': '134.2500',
#   '3. low': '121.9000',
#   '4. close': '122.3900',
#   '5. adjusted close': '67.6020',
#   '6. volume': '156110600',
#   '7. dividend amount': '0.0000'},
#  '2009-12-31': {'1. open': '127.2900',
#   '2. high': '132.8500',
#   '3. low': '126.0000',
#   '4. close': '130.9000',
#   '5. adjusted close': '72.3025',
#   '6. volume': '124475900',
#   '7. dividend amount': '0.0000'},
#  '2009-11-30': {'1. open': '120.6100',
#   '2. high': '128.9400',
#   '3. low': '119.5000',
#   '4. close': '126.3500',
#   '5. adjusted close': '69.7893',
#   '6. volume': '110748200',
#   '7. dividend amount': '0.5500'},
#  '2009-10-30': {'1. open': '119.3900',
#   '2. high': '128.6100',
#   '3. low': '117.2600',
#   '4. close': '120.6100',
#   '5. adjusted close': '66.3234',
#   '6. volume': '183531100',
#   '7. dividend amount': '0.0000'},
#  '2009-09-30': {'1. open': '117.6700',
#   '2. high': '122.8800',
#   '3. low': '115.1500',
#   '4. close': '119.6100',
#   '5. adjusted close': '65.7735',
#   '6. volume': '131522200',
#   '7. dividend amount': '0.0000'},
#  '2009-08-31': {'1. open': '118.8800',
#   '2. high': '120.8800',
#   '3. low': '116.1200',
#   '4. close': '118.0500',
#   '5. adjusted close': '64.9157',
#   '6. volume': '112480200',
#   '7. dividend amount': '0.5500'},
#  '2009-07-31': {'1. open': '105.0000',
#   '2. high': '119.3700',
#   '3. low': '99.5000',
#   '4. close': '117.9300',
#   '5. adjusted close': '64.5473',
#   '6. volume': '176171400',
#   '7. dividend amount': '0.0000'},
#  '2009-06-30': {'1. open': '106.9400',
#   '2. high': '110.6400',
#   '3. low': '103.5100',
#   '4. close': '104.4200',
#   '5. adjusted close': '57.1528',
#   '6. volume': '160502100',
#   '7. dividend amount': '0.0000'},
#  '2009-05-29': {'1. open': '103.7800',
#   '2. high': '106.8200',
#   '3. low': '99.8300',
#   '4. close': '106.2800',
#   '5. adjusted close': '58.1708',
#   '6. volume': '153084700',
#   '7. dividend amount': '0.5500'},
#  '2009-04-30': {'1. open': '96.1300',
#   '2. high': '106.0500',
#   '3. low': '95.7000',
#   '4. close': '103.2100',
#   '5. adjusted close': '56.1951',
#   '6. volume': '213623100',
#   '7. dividend amount': '0.0000'},
#  '2009-03-31': {'1. open': '91.1700',
#   '2. high': '99.8600',
#   '3. low': '83.0200',
#   '4. close': '96.8900',
#   '5. adjusted close': '52.7540',
#   '6. volume': '286114500',
#   '7. dividend amount': '0.0000'},
#  '2009-02-27': {'1. open': '90.6000',
#   '2. high': '97.1000',
#   '3. low': '82.8500',
#   '4. close': '92.0300',
#   '5. adjusted close': '50.1079',
#   '6. volume': '223017600',
#   '7. dividend amount': '0.5000'},
#  '2009-01-30': {'1. open': '83.8900',
#   '2. high': '94.9400',
#   '3. low': '81.7600',
#   '4. close': '91.6500',
#   '5. adjusted close': '49.6428',
#   '6. volume': '208959400',
#   '7. dividend amount': '0.0000'},
#  '2008-12-31': {'1. open': '80.9500',
#   '2. high': '87.2700',
#   '3. low': '75.3100',
#   '4. close': '84.1600',
#   '5. adjusted close': '45.5858',
#   '6. volume': '188846100',
#   '7. dividend amount': '0.0000'},
#  '2008-11-28': {'1. open': '92.6400',
#   '2. high': '94.7600',
#   '3. low': '69.5000',
#   '4. close': '81.6000',
#   '5. adjusted close': '44.1991',
#   '6. volume': '218313000',
#   '7. dividend amount': '0.5000'},
#  '2008-10-31': {'1. open': '115.5100',
#   '2. high': '116.8000',
#   '3. low': '78.8200',
#   '4. close': '92.9700',
#   '5. adjusted close': '50.0638',
#   '6. volume': '314972000',
#   '7. dividend amount': '0.0000'},
#  '2008-09-30': {'1. open': '122.8700',
#   '2. high': '124.0000',
#   '3. low': '109.9500',
#   '4. close': '116.9600',
#   '5. adjusted close': '62.9823',
#   '6. volume': '218411700',
#   '7. dividend amount': '0.0000'},
#  '2008-08-29': {'1. open': '128.5200',
#   '2. high': '129.9700',
#   '3. low': '121.5000',
#   '4. close': '121.7300',
#   '5. adjusted close': '65.5509',
#   '6. volume': '137028800',
#   '7. dividend amount': '0.5000'},
#  '2008-07-31': {'1. open': '117.5000',
#   '2. high': '130.9300',
#   '3. low': '116.6000',
#   '4. close': '127.9800',
#   '5. adjusted close': '68.6507',
#   '6. volume': '200876500',
#   '7. dividend amount': '0.0000'},
#  '2008-06-30': {'1. open': '128.6700',
#   '2. high': '129.3700',
#   '3. low': '118.1500',
#   '4. close': '118.5300',
#   '5. adjusted close': '63.5816',
#   '6. volume': '152327500',
#   '7. dividend amount': '0.0000'},
#  '2008-05-30': {'1. open': '121.0600',
#   '2. high': '129.9900',
#   '3. low': '120.7800',
#   '4. close': '129.4300',
#   '5. adjusted close': '69.4285',
#   '6. volume': '159517500',
#   '7. dividend amount': '0.5000'},
#  '2008-04-30': {'1. open': '115.1400',
#   '2. high': '125.0000',
#   '3. low': '113.8600',
#   '4. close': '120.7000',
#   '5. adjusted close': '64.4859',
#   '6. volume': '192087200',
#   '7. dividend amount': '0.0000'},
#  '2008-03-31': {'1. open': '114.0900',
#   '2. high': '119.7900',
#   '3. low': '111.8000',
#   '4. close': '115.1400',
#   '5. adjusted close': '61.5153',
#   '6. volume': '179284200',
#   '7. dividend amount': '0.0000'},
#  '2008-02-29': {'1. open': '107.2100',
#   '2. high': '116.6300',
#   '3. low': '100.6000',
#   '4. close': '113.8600',
#   '5. adjusted close': '60.8315',
#   '6. volume': '168280800',
#   '7. dividend amount': '0.4000'},
#  '2008-01-31': {'1. open': '108.9900',
#   '2. high': '108.9900',
#   '3. low': '97.0400',
#   '4. close': '107.1100',
#   '5. adjusted close': '57.0051',
#   '6. volume': '247523900',
#   '7. dividend amount': '0.0000'},
#  '2007-12-31': {'1. open': '105.4500',
#   '2. high': '112.1900',
#   '3. low': '104.0000',
#   '4. close': '108.1000',
#   '5. adjusted close': '57.5320',
#   '6. volume': '134151600',
#   '7. dividend amount': '0.0000'},
#  '2007-11-30': {'1. open': '115.5000',
#   '2. high': '116.0900',
#   '3. low': '99.2700',
#   '4. close': '105.1800',
#   '5. adjusted close': '55.9779',
#   '6. volume': '200920600',
#   '7. dividend amount': '0.4000'},
#  '2007-10-31': {'1. open': '117.6100',
#   '2. high': '121.4600',
#   '3. low': '110.9600',
#   '4. close': '116.1200',
#   '5. adjusted close': '61.5785',
#   '6. volume': '171669000',
#   '7. dividend amount': '0.0000'},
#  '2007-09-28': {'1. open': '116.3400',
#   '2. high': '118.8900',
#   '3. low': '114.3000',
#   '4. close': '117.8000',
#   '5. adjusted close': '62.4694',
#   '6. volume': '132233800',
#   '7. dividend amount': '0.0000'},
#  '2007-08-31': {'1. open': '110.3900',
#   '2. high': '117.3500',
#   '3. low': '103.7000',
#   '4. close': '116.6900',
#   '5. adjusted close': '61.8808',
#   '6. volume': '202871500',
#   '7. dividend amount': '0.4000'},
#  '2007-07-31': {'1. open': '105.3900',
#   '2. high': '118.8200',
#   '3. low': '104.5800',
#   '4. close': '110.6500',
#   '5. adjusted close': '58.4708',
#   '6. volume': '212757600',
#   '7. dividend amount': '0.0000'},
#  '2007-06-29': {'1. open': '106.6200',
#   '2. high': '107.2400',
#   '3. low': '101.5600',
#   '4. close': '105.2500',
#   '5. adjusted close': '55.6173',
#   '6. volume': '169602000',
#   '7. dividend amount': '0.0000'},
#  '2007-05-31': {'1. open': '102.0600',
#   '2. high': '108.0500',
#   '3. low': '101.3500',
#   '4. close': '106.6000',
#   '5. adjusted close': '56.3306',
#   '6. volume': '146441400',
#   '7. dividend amount': '0.4000'},
#  '2007-04-30': {'1. open': '94.5100',
#   '2. high': '103.0000',
#   '3. low': '93.9110',
#   '4. close': '102.2100',
#   '5. adjusted close': '53.8025',
#   '6. volume': '166807200',
#   '7. dividend amount': '0.0000'},
#  '2007-03-30': {'1. open': '90.2500',
#   '2. high': '95.8100',
#   '3. low': '88.7700',
#   '4. close': '94.2600',
#   '5. adjusted close': '49.6177',
#   '6. volume': '163194500',
#   '7. dividend amount': '0.0000'},
#  '2007-02-28': {'1. open': '98.9700',
#   '2. high': '100.4400',
#   '3. low': '92.4700',
#   '4. close': '92.9400',
#   '5. adjusted close': '48.9228',
#   '6. volume': '125776200',
#   '7. dividend amount': '0.3000'},
#  '2007-01-31': {'1. open': '97.1700',
#   '2. high': '100.9000',
#   '3. low': '94.5500',
#   '4. close': '99.1500',
#   '5. adjusted close': '52.0349',
#   '6. volume': '192702000',
#   '7. dividend amount': '0.0000'},
#  '2006-12-29': {'1. open': '91.9000',
#   '2. high': '97.8800',
#   '3. low': '90.5500',
#   '4. close': '97.1500',
#   '5. adjusted close': '50.9853',
#   '6. volume': '104470200',
#   '7. dividend amount': '0.0000'},
#  '2006-11-30': {'1. open': '92.5000',
#   '2. high': '94.0500',
#   '3. low': '90.4300',
#   '4. close': '91.9200',
#   '5. adjusted close': '48.2405',
#   '6. volume': '104430000',
#   '7. dividend amount': '0.3000'},
#  '2006-10-31': {'1. open': '81.7600',
#   '2. high': '92.6800',
#   '3. low': '81.5600',
#   '4. close': '92.3300',
#   '5. adjusted close': '48.2992',
#   '6. volume': '170367300',
#   '7. dividend amount': '0.0000'},
#  '2006-09-29': {'1. open': '81.1300',
#   '2. high': '83.7900',
#   '3. low': '79.3100',
#   '4. close': '81.9400',
#   '5. adjusted close': '42.8640',
# ...
#   '2. high': '84.4500',
#   '3. low': '80.6300',
#   '4. close': '82.3400',
#   '5. adjusted close': '42.7477',
#   '6. volume': '114007000',
#   '7. dividend amount': '0.0000'},
#  '2006-03-31': {'1. open': '80.0100',
#   '2. high': '84.9900',
#   '3. low': '79.5100',
#   '4. close': '82.4700',
#   '5. adjusted close': '42.8152',
#   '6. volume': '111514900',
#   '7. dividend amount': '0.0000'},
#  '2006-02-28': {'1. open': '80.9000',
#   '2. high': '82.2400',
#   '3. low': '78.9300',
#   '4. close': '80.2400',
#   '5. adjusted close': '41.6575',
#   '6. volume': '111052200',
#   '7. dividend amount': '0.2000'},
#  '2006-01-31': {'1. open': '82.4500',
#   '2. high': '85.0300',
#   '3. low': '80.2100',
#   '4. close': '81.3000',
#   '5. adjusted close': '42.1036',
#   '6. volume': '146491600',
#   '7. dividend amount': '0.0000'},
#  '2005-12-30': {'1. open': '89.1500',
#   '2. high': '89.9200',
#   '3. low': '81.5600',
#   '4. close': '82.2000',
#   '5. adjusted close': '42.5697',
#   '6. volume': '120052400',
#   '7. dividend amount': '0.0000'},
#  '2005-11-30': {'1. open': '81.8500',
#   '2. high': '89.9400',
#   '3. low': '80.6400',
#   '4. close': '88.9000',
#   '5. adjusted close': '46.0394',
#   '6. volume': '110664500',
#   '7. dividend amount': '0.2000'},
#  '2005-10-31': {'1. open': '80.2200',
#   '2. high': '84.6000',
#   '3. low': '78.7000',
#   '4. close': '81.8800',
#   '5. adjusted close': '42.3022',
#   '6. volume': '139881800',
#   '7. dividend amount': '0.0000'},
#  '2005-09-30': {'1. open': '80.1600',
#   '2. high': '82.1100',
#   '3. low': '76.9300',
#   '4. close': '80.2200',
#   '5. adjusted close': '41.4446',
#   '6. volume': '115681400',
#   '7. dividend amount': '0.0000'},
#  '2005-08-31': {'1. open': '83.0000',
#   '2. high': '84.2000',
#   '3. low': '79.8700',
#   '4. close': '80.6200',
#   '5. adjusted close': '41.6512',
#   '6. volume': '105031100',
#   '7. dividend amount': '0.2000'},
#  '2005-07-29': {'1. open': '74.3000',
#   '2. high': '85.1100',
#   '3. low': '74.1600',
#   '4. close': '83.4600',
#   '5. adjusted close': '43.0153',
#   '6. volume': '156801500',
#   '7. dividend amount': '0.0000'},
#  '2005-06-30': {'1. open': '75.5700',
#   '2. high': '77.7300',
#   '3. low': '73.4500',
#   '4. close': '74.2000',
#   '5. adjusted close': '38.2427',
#   '6. volume': '135542800',
#   '7. dividend amount': '0.0000'},
#  '2005-05-31': {'1. open': '76.8800',
#   '2. high': '78.1100',
#   '3. low': '72.5000',
#   '4. close': '75.5500',
#   '5. adjusted close': '38.9385',
#   '6. volume': '138416000',
#   '7. dividend amount': '0.2000'},
#  '2005-04-29': {'1. open': '91.4900',
#   '2. high': '91.7600',
#   '3. low': '71.8500',
#   '4. close': '76.3800',
#   '5. adjusted close': '39.2619',
#   '6. volume': '216745500',
#   '7. dividend amount': '0.0000'},
#  '2005-03-31': {'1. open': '92.6400',
#   '2. high': '93.7300',
#   '3. low': '89.0900',
#   '4. close': '91.3800',
#   '5. adjusted close': '46.9724',
#   '6. volume': '106145200',
#   '7. dividend amount': '0.0000'},
#  '2005-02-28': {'1. open': '93.6700',
#   '2. high': '94.9700',
#   '3. low': '91.5500',
#   '4. close': '92.5800',
#   '5. adjusted close': '47.5892',
#   '6. volume': '79707700',
#   '7. dividend amount': '0.1800'},
#  '2005-01-31': {'1. open': '98.9700',
#   '2. high': '99.1000',
#   '3. low': '91.4400',
#   '4. close': '93.4200',
#   '5. adjusted close': '47.9294',
#   '6. volume': '114459000',
#   '7. dividend amount': '0.0000'},
#  '2004-12-31': {'1. open': '94.5000',
#   '2. high': '99.0000',
#   '3. low': '94.4700',
#   '4. close': '98.5800',
#   '5. adjusted close': '50.5767',
#   '6. volume': '108170400',
#   '7. dividend amount': '0.0000'},
#  '2004-11-30': {'1. open': '89.3300',
#   '2. high': '96.6300',
#   '3. low': '89.2300',
#   '4. close': '94.2400',
#   '5. adjusted close': '48.3501',
#   '6. volume': '114982100',
#   '7. dividend amount': '0.1800'},
#  '2004-10-29': {'1. open': '85.9500',
#   '2. high': '90.2700',
#   '3. low': '84.2900',
#   '4. close': '89.7500',
#   '5. adjusted close': '45.9579',
#   '6. volume': '118116100',
#   '7. dividend amount': '0.0000'},
#  '2004-09-30': {'1. open': '84.0500',
#   '2. high': '87.2800',
#   '3. low': '83.2400',
#   '4. close': '85.7400',
#   '5. adjusted close': '43.9045',
#   '6. volume': '93906300',
#   '7. dividend amount': '0.0000'},
#  '2004-08-31': {'1. open': '86.8700',
#   '2. high': '87.3900',
#   '3. low': '81.9000',
#   '4. close': '84.6900',
#   '5. adjusted close': '43.3668',
#   '6. volume': '91169700',
#   '7. dividend amount': '0.1800'},
#  '2004-07-30': {'1. open': '88.2800',
#   '2. high': '88.4400',
#   '3. low': '83.4200',
#   '4. close': '87.0700',
#   '5. adjusted close': '44.4896',
#   '6. volume': '121001000',
#   '7. dividend amount': '0.0000'},
#  '2004-06-30': {'1. open': '88.0900',
#   '2. high': '91.2100',
#   '3. low': '87.3000',
#   '4. close': '88.1500',
#   '5. adjusted close': '45.0415',
#   '6. volume': '91968600',
#   '7. dividend amount': '0.0000'},
#  '2004-05-28': {'1. open': '88.1300',
#   '2. high': '89.7500',
#   '3. low': '85.1200',
#   '4. close': '88.5900',
#   '5. adjusted close': '45.2663',
#   '6. volume': '104707300',
#   '7. dividend amount': '0.1800'},
#  '2004-04-30': {'1. open': '91.6700',
#   '2. high': '94.5500',
#   '3. low': '88.0100',
#   '4. close': '88.1700',
#   '5. adjusted close': '44.9601',
#   '6. volume': '110632000',
#   '7. dividend amount': '0.0000'},
#  '2004-03-31': {'1. open': '96.5000',
#   '2. high': '97.6000',
#   '3. low': '90.2800',
#   '4. close': '91.8400',
#   '5. adjusted close': '46.8315',
#   '6. volume': '124483700',
#   '7. dividend amount': '0.0000'},
#  '2004-02-27': {'1. open': '99.1500',
#   '2. high': '100.4300',
#   '3. low': '95.2000',
#   '4. close': '96.5000',
#   '5. adjusted close': '49.2078',
#   '6. volume': '97741900',
#   '7. dividend amount': '0.1600'},
#  '2004-01-30': {'1. open': '92.8600',
#   '2. high': '99.8500',
#   '3. low': '89.0100',
#   '4. close': '99.2300',
#   '5. adjusted close': '50.5182',
#   '6. volume': '139368500',
#   '7. dividend amount': '0.0000'},
#  '2003-12-31': {'1. open': '90.9000',
#   '2. high': '94.1200',
#   '3. low': '90.0300',
#   '4. close': '92.6800',
#   '5. adjusted close': '47.1835',
#   '6. volume': '116103600',
#   '7. dividend amount': '0.0000'},
#  '2003-11-28': {'1. open': '89.9000',
#   '2. high': '91.4800',
#   '3. low': '87.7200',
#   '4. close': '90.5400',
#   '5. adjusted close': '46.0941',
#   '6. volume': '97966100',
#   '7. dividend amount': '0.1600'},
#  '2003-10-31': {'1. open': '88.7500',
#   '2. high': '94.5400',
#   '3. low': '87.5300',
#   '4. close': '89.4800',
#   '5. adjusted close': '45.4730',
#   '6. volume': '156145400',
#   '7. dividend amount': '0.0000'},
#  '2003-09-30': {'1. open': '82.4000',
#   '2. high': '93.4700',
#   '3. low': '82.3000',
#   '4. close': '88.3300',
#   '5. adjusted close': '44.8886',
#   '6. volume': '171943100',
#   '7. dividend amount': '0.0000'},
#  '2003-08-29': {'1. open': '81.1500',
#   '2. high': '84.7200',
#   '3. low': '78.7300',
#   '4. close': '82.0100',
#   '5. adjusted close': '41.6768',
#   '6. volume': '113895200',
#   '7. dividend amount': '0.1600'},
#  '2003-07-31': {'1. open': '81.4000',
#   '2. high': '87.0300',
#   '3. low': '80.5800',
#   '4. close': '81.2500',
#   '5. adjusted close': '41.2079',
#   '6. volume': '153915600',
#   '7. dividend amount': '0.0000'},
#  '2003-06-30': {'1. open': '89.0000',
#   '2. high': '89.0800',
#   '3. low': '79.8100',
#   '4. close': '82.5000',
#   '5. adjusted close': '41.8419',
#   '6. volume': '184488300',
#   '7. dividend amount': '0.0000'},
#  '2003-05-30': {'1. open': '85.3000',
#   '2. high': '90.4000',
#   '3. low': '84.4500',
#   '4. close': '88.0400',
#   '5. adjusted close': '44.6516',
#   '6. volume': '149548000',
#   '7. dividend amount': '0.1600'},
#  '2003-04-30': {'1. open': '78.5000',
#   '2. high': '86.4900',
#   '3. low': '78.1200',
#   '4. close': '84.9000',
#   '5. adjusted close': '42.9797',
#   '6. volume': '177874300',
#   '7. dividend amount': '0.0000'},
#  '2003-03-31': {'1. open': '78.9000',
#   '2. high': '84.9000',
#   '3. low': '73.1700',
#   '4. close': '78.4300',
#   '5. adjusted close': '39.7044',
#   '6. volume': '191937200',
#   '7. dividend amount': '0.0000'},
#  '2003-02-28': {'1. open': '78.2000',
#   '2. high': '80.0500',
#   '3. low': '74.3100',
#   '4. close': '77.9500',
#   '5. adjusted close': '39.4614',
#   '6. volume': '145672700',
#   '7. dividend amount': '0.1500'},
#  '2003-01-31': {'1. open': '78.8000',
#   '2. high': '88.9500',
#   '3. low': '77.0200',
#   '4. close': '78.2000',
#   '5. adjusted close': '39.5115',
#   '6. volume': '193933500',
#   '7. dividend amount': '0.0000'},
#  '2002-12-31': {'1. open': '88.6000',
#   '2. high': '89.4600',
#   '3. low': '75.6000',
#   '4. close': '77.5000',
#   '5. adjusted close': '39.1578',
#   '6. volume': '151563500',
#   '7. dividend amount': '0.0000'},
#  '2002-11-29': {'1. open': '78.9000',
#   '2. high': '88.1100',
#   '3. low': '76.7000',
#   '4. close': '86.9200',
#   '5. adjusted close': '43.9174',
#   '6. volume': '184438100',
#   '7. dividend amount': '0.1500'},
#  '2002-10-31': {'1. open': '59.2000',
#   '2. high': '79.7900',
#   '3. low': '54.0100',
#   '4. close': '78.9400',
#   '5. adjusted close': '39.8121',
#   '6. volume': '285626300',
#   '7. dividend amount': '0.0000'},
#  '2002-09-30': {'1. open': '74.2000',
#   '2. high': '77.5000',
#   '3. low': '57.9900',
#   '4. close': '58.3100',
#   '5. adjusted close': '29.4077',
#   '6. volume': '185664400',
#   '7. dividend amount': '0.0000'},
#  '2002-08-30': {'1. open': '70.4000',
#   '2. high': '82.8500',
#   '3. low': '65.8500',
#   '4. close': '75.3800',
#   '5. adjusted close': '38.0167',
#   '6. volume': '166322300',
#   '7. dividend amount': '0.1500'},
#  '2002-07-31': {'1. open': '72.0100',
#   '2. high': '74.2000',
#   '3. low': '65.7000',
#   '4. close': '70.4000',
#   '5. adjusted close': '35.4283',
#   '6. volume': '246256900',
#   '7. dividend amount': '0.0000'},
#  '2002-06-28': {'1. open': '80.7500',
#   '2. high': '80.9500',
#   '3. low': '66.1000',
#   '4. close': '72.0000',
#   '5. adjusted close': '36.2335',
#   '6. volume': '190980700',
#   '7. dividend amount': '0.0000'},
#  '2002-05-31': {'1. open': '83.8500',
#   '2. high': '86.4900',
#   '3. low': '75.9200',
#   '4. close': '80.4500',
#   '5. adjusted close': '40.4859',
#   '6. volume': '172738400',
#   '7. dividend amount': '0.1500'},
#  '2002-04-30': {'1. open': '104.0000',
#   '2. high': '104.0000',
#   '3. low': '83.3400',
#   '4. close': '83.7600',
#   '5. adjusted close': '42.0751',
#   '6. volume': '246503300',
#   '7. dividend amount': '0.0000'},
#  '2002-03-28': {'1. open': '98.6000',
#   '2. high': '108.8500',
#   '3. low': '98.5000',
#   '4. close': '104.0000',
#   '5. adjusted close': '52.2422',
#   '6. volume': '151268500',
#   '7. dividend amount': '0.0000'},
#  '2002-02-28': {'1. open': '107.6400',
#   '2. high': '109.3000',
#   '3. low': '95.7600',
#   '4. close': '98.1200',
#   '5. adjusted close': '49.2885',
#   '6. volume': '172321000',
#   '7. dividend amount': '0.1400'},
#  '2002-01-31': {'1. open': '120.6000',
#   '2. high': '126.3900',
#   '3. low': '101.0000',
#   '4. close': '107.8900',
#   '5. adjusted close': '54.1252',
#   '6. volume': '193562900',
#   '7. dividend amount': '0.0000'},
#  '2001-12-31': {'1. open': '114.8000',
#   '2. high': '124.7000',
#   '3. low': '113.2100',
#   '4. close': '120.9600',
#   '5. adjusted close': '60.6820',
#   '6. volume': '133393800',
#   '7. dividend amount': '0.0000'},
#  '2001-11-30': {'1. open': '107.2500',
#   '2. high': '117.0000',
#   '3. low': '106.9000',
#   '4. close': '115.5900',
#   '5. adjusted close': '57.9881',
#   '6. volume': '135136300',
#   '7. dividend amount': '0.1400'},
#  '2001-10-31': {'1. open': '91.7200',
#   '2. high': '112.1000',
#   '3. low': '91.3400',
#   '4. close': '108.0700',
#   '5. adjusted close': '54.1489',
#   '6. volume': '224351500',
#   '7. dividend amount': '0.0000'},
#  '2001-09-28': {'1. open': '100.1500',
#   '2. high': '103.1300',
#   '3. low': '87.4900',
#   '4. close': '91.7200',
#   '5. adjusted close': '45.9567',
#   '6. volume': '189312500',
#   '7. dividend amount': '0.0000'},
#  '2001-08-31': {'1. open': '105.3500',
#   '2. high': '110.0900',
#   '3. low': '98.8600',
#   '4. close': '99.9500',
#   '5. adjusted close': '50.0804',
#   '6. volume': '143401500',
#   '7. dividend amount': '0.1400'},
#  '2001-07-31': {'1. open': '113.5000',
#   '2. high': '115.4000',
#   '3. low': '101.5600',
#   '4. close': '105.2100',
#   '5. adjusted close': '52.6452',
#   '6. volume': '161016400',
#   '7. dividend amount': '0.0000'},
#  '2001-06-29': {'1. open': '112.5000',
#   '2. high': '119.0000',
#   '3. low': '111.1000',
#   '4. close': '113.5000',
#   '5. adjusted close': '56.7933',
#   '6. volume': '142929700',
#   '7. dividend amount': '0.0000'},
#  '2001-05-31': {'1. open': '115.8500',
#   '2. high': '119.9000',
#   '3. low': '110.9600',
#   '4. close': '111.8000',
#   '5. adjusted close': '55.9427',
#   '6. volume': '159356200',
#   '7. dividend amount': '0.1400'},
#  '2001-04-30': {'1. open': '97.4500',
#   '2. high': '118.0500',
#   '3. low': '90.0500',
#   '4. close': '115.1400',
#   '5. adjusted close': '57.5455',
#   '6. volume': '226210900',
#   '7. dividend amount': '0.0000'},
#  '2001-03-30': {'1. open': '99.3000',
#   '2. high': '108.4000',
#   '3. low': '87.6500',
#   '4. close': '96.1800',
#   '5. adjusted close': '48.0695',
#   '6. volume': '254550000',
#   '7. dividend amount': '0.0000'},
#  '2001-02-28': {'1. open': '112.4000',
#   '2. high': '118.6400',
#   '3. low': '99.1000',
#   '4. close': '99.9000',
#   '5. adjusted close': '49.9287',
#   '6. volume': '156438900',
#   '7. dividend amount': '0.1300'},
#  '2001-01-31': {'1. open': '84.5000',
#   '2. high': '116.7500',
#   '3. low': '83.7500',
#   '4. close': '112.0000',
#   '5. adjusted close': '55.9140',
#   '6. volume': '198962600',
#   '7. dividend amount': '0.0000'},
#  '2000-12-29': {'1. open': '94.4400',
#   '2. high': '104.7500',
#   '3. low': '80.0600',
#   '4. close': '85.0000',
#   '5. adjusted close': '42.4347',
#   '6. volume': '167790700',
#   '7. dividend amount': '0.0000'},
#  '2000-11-30': {'1. open': '98.4400',
#   '2. high': '104.3700',
#   '3. low': '91.6200',
#   '4. close': '93.5000',
#   '5. adjusted close': '46.6782',
#   '6. volume': '130411900',
#   '7. dividend amount': '0.1300'},
#  '2000-10-31': {'1. open': '112.6200',
#   '2. high': '119.6200',
#   '3. low': '86.9400',
#   '4. close': '98.5000',
#   '5. adjusted close': '49.1105',
#   '6. volume': '223510000',
#   '7. dividend amount': '0.0000'},
#  '2000-09-29': {'1. open': '133.0600',
#   '2. high': '134.9400',
#   '3. low': '110.2500',
#   '4. close': '112.6200',
#   '5. adjusted close': '56.1505',
#   '6. volume': '107468400',
#   '7. dividend amount': '0.0000'},
#  '2000-08-31': {'1. open': '112.0000',
#   '2. high': '134.2500',
#   '3. low': '110.2500',
#   '4. close': '132.0200',
#   '5. adjusted close': '65.8230',
#   '6. volume': '121998000',
#   '7. dividend amount': '0.1300'},
#  '2000-07-31': {'1. open': '108.7500',
#   '2. high': '117.8100',
#   '3. low': '100.0000',
#   '4. close': '112.2500',
#   '5. adjusted close': '55.9049',
#   '6. volume': '150130400',
#   '7. dividend amount': '0.0000'},
#  '2000-06-30': {'1. open': '107.5600',
#   '2. high': '122.3100',
#   '3. low': '105.5000',
#   '4. close': '109.5600',
#   '5. adjusted close': '54.5652',
#   '6. volume': '136216300',
#   '7. dividend amount': '0.0000'},
#  '2000-05-31': {'1. open': '112.5000',
#   '2. high': '113.6200',
#   '3. low': '102.0000',
#   '4. close': '107.3100',
#   '5. adjusted close': '53.4446',
#   '6. volume': '123803200',
#   '7. dividend amount': '0.1300'},
#  '2000-04-28': {'1. open': '120.0000',
#   '2. high': '128.0000',
#   '3. low': '101.2500',
#   '4. close': '111.5000',
#   '5. adjusted close': '55.4657',
#   '6. volume': '168464800',
#   '7. dividend amount': '0.0000'},
#  '2000-03-31': {'1. open': '102.0000',
#   '2. high': '128.2500',
#   '3. low': '99.5000',
#   '4. close': '118.3700',
#   '5. adjusted close': '58.8832',
#   '6. volume': '194329000',
#   '7. dividend amount': '0.0000'},
#  '2000-02-29': {'1. open': '112.3700',
#   '2. high': '119.7500',
#   '3. low': '100.9400',
#   '4. close': '102.7500',
#   '5. adjusted close': '51.1130',
#   '6. volume': '133524400',
#   '7. dividend amount': '0.1200'},
#  '2000-01-31': {'1. open': '112.4400',
#   '2. high': '124.7500',
#   '3. low': '109.6200',
#   '4. close': '112.2500',
#   '5. adjusted close': '55.7824',
#   '6. volume': '175259600',
#   '7. dividend amount': '0.0000'},
#  '1999-12-31': {'1. open': '102.5600',
#   '2. high': '122.1200',
#   '3. low': '102.2500',
#   '4. close': '107.8700',
#   '5. adjusted close': '53.6058',
#   '6. volume': '158626300',
#   '7. dividend amount': '0.0000'}}

# %%
import pandas as pd

df = pd.DataFrame.from_dict(time_series, orient="index")
df.index = pd.to_datetime(df.index)
df = df.sort_index()

df.head()
# Out:
#              1. open   2. high    3. low  4. close 5. adjusted close  \
# 1999-12-31  102.5600  122.1200  102.2500  107.8700           53.6058
# 2000-01-31  112.4400  124.7500  109.6200  112.2500           55.7824
# 2000-02-29  112.3700  119.7500  100.9400  102.7500           51.1130
# 2000-03-31  102.0000  128.2500   99.5000  118.3700           58.8832
# 2000-04-28  120.0000  128.0000  101.2500  111.5000           55.4657
#
#             6. volume 7. dividend amount
# 1999-12-31  158626300             0.0000
# 2000-01-31  175259600             0.0000
# 2000-02-29  133524400             0.1200
# 2000-03-31  194329000             0.0000
# 2000-04-28  168464800             0.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 309 entries, 1999-12-31 to 2025-08-20
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   1. open             309 non-null    object
#  1   2. high             309 non-null    object
#  2   3. low              309 non-null    object
#  3   4. close            309 non-null    object
#  4   5. adjusted close   309 non-null    object
#  5   6. volume           309 non-null    object
#  6   7. dividend amount  309 non-null    object
# dtypes: object(7)
# memory usage: 19.3+ KB

# %%
df.describe()
# Out:
#          1. open   2. high   3. low  4. close 5. adjusted close  6. volume  \
# count        309       309      309       309               309        309
# unique       297       306      303       307               309        309
# top     145.0000  147.5000  99.5000  112.2500           53.6058  158626300
# freq           3         2        2         2                 1          1
#
#        7. dividend amount
# count                 309
# unique                 28
# top                0.0000
# freq                  206

# %%
df.columns = [col.split(" ", 1)[1] for col in df.columns]
df.head()
# Out:
#                 open      high       low     close adjusted close     volume  \
# 1999-12-31  102.5600  122.1200  102.2500  107.8700        53.6058  158626300
# 2000-01-31  112.4400  124.7500  109.6200  112.2500        55.7824  175259600
# 2000-02-29  112.3700  119.7500  100.9400  102.7500        51.1130  133524400
# 2000-03-31  102.0000  128.2500   99.5000  118.3700        58.8832  194329000
# 2000-04-28  120.0000  128.0000  101.2500  111.5000        55.4657  168464800
#
#            dividend amount
# 1999-12-31          0.0000
# 2000-01-31          0.0000
# 2000-02-29          0.1200
# 2000-03-31          0.0000
# 2000-04-28          0.0000

# %%
import os


required_cols = ['open', 'high', 'low', 'close', 'adjusted close', 'volume',
       'dividend amount']

print("Validation Results:")
print("Required columns present:", all(col in df.columns for col in required_cols))
print("NA counts:\n", df.isna().sum())
print("Shape:", df.shape)


data_raw = "../data/raw/"
os.makedirs(data_raw, exist_ok=True)
raw_path = os.path.join(data_raw, "time_series_raw.csv")
df.to_csv(raw_path)
print(f"Saved to {raw_path}")
# Out:
# Validation Results:
# Required columns present: True
# NA counts:
#  open               0
# high               0
# low                0
# close              0
# adjusted close     0
# volume             0
# dividend amount    0
# dtype: int64
# Shape: (309, 7)
# Saved to ../data/raw/time_series_raw.csv

# %%
df = df.apply(pd.to_numeric, errors="coerce")

if df["volume"].isna().sum() == 0:
    df["volume"] = df["volume"].astype(int)

print(df.dtypes)
# Out:
# open               float64
# high               float64
# low                float64
# close              float64
# adjusted close     float64
# volume               int64
# dividend amount    float64
# dtype: object

# %% [markdown]
# ### Web Scraping

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

response = requests.get("https://web-scraping.dev/product/1")
html = response.text
soup = BeautifulSoup(html, "lxml")

table = soup.find_all('table', {'class': 'table-product'})[1]

headers = [el.text.strip() for el in table.find_all('tr')[0].find_all('th')]
rows = []
for row in table.find_all('tr')[1:]:
    rows.append([el.text.strip() for el in row.find_all('td')])

df = pd.DataFrame(rows, columns=headers)
df.to_csv("../data/raw/table.csv", index=False)

# %%
df = pd.read_csv("../data/raw/table.csv")
df.head()
# Out:
#   Version Package Weight Package Dimension     Variants   Delivery Type
# 0  Pack 1        1,00 kg        100x230 cm  6 available  1 Day shipping
# 1  Pack 2        2,11 kg        200x460 cm  6 available  1 Day shipping
# 2  Pack 3        3,22 kg        300x690 cm  6 available  1 Day shipping
# 3  Pack 4        4,33 kg        400x920 cm  6 available  1 Day shipping
# 4  Pack 5        5,44 kg       500x1150 cm  6 available  1 Day shipping

# %%
import os
gitignore_path = ".gitignore"

if os.path.exists(gitignore_path):
    with open(gitignore_path, "r") as f:
        lines = [line.strip() for line in f.readlines()]
    if ".env" in lines:
        print(".env is ignored in .gitignore")
    else:
        print(".env is NOT ignored in .gitignore")
else:
    print(".gitignore file not found")
# Out:
# .env is ignored in .gitignore
